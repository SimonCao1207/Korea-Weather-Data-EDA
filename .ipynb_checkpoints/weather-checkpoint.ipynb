# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv("OBS_ASOS_TIM_20220815084124.csv", encoding='euc-kr') ## 1 week data (from 08-14 of August)

df = pd.read_csv("OBS_ASOS_MNH_20220815103633.csv", encoding='euc-kr') ## 1 month data (from May->August)

df.head()
# Out:
#    지점  지점명       일시  평균기온(°C)  평균최고기온(°C)  평균최저기온(°C)  최고기온(°C)  최저기온(°C)  \
# 0  90   속초  2022-05      18.5        23.7        13.1      33.5       5.8
# 1  90   속초  2022-06      20.9        24.7        17.6      34.6      10.1
# 2  90   속초  2022-07      24.3        27.7        21.9      33.4      18.8
# 3  90   속초  2022-08       NaN         NaN         NaN      35.5      20.3
# 4  93  북춘천  2022-05      17.2        25.0         9.4      30.7       2.4
#
#    최고기온 나타난날(yyyymmdd)  최저기온 나타난날(yyyymmdd)  ...  평균지면온도(°C)  0.05m평균지중온도(°C)  \
# 0             20220528             20220502  ...        24.0              NaN
# 1             20220625             20220608  ...        24.8              NaN
# 2             20220708             20220723  ...        28.5              NaN
# 3             20220806             20220810  ...         NaN              NaN
# 4             20220524             20220501  ...        22.7             21.0
#
#    0.1m평균지중온도(°C)  0.2m평균지중온도(°C)  0.3m평균지중온도(°C)  0.5m평균지중온도(°C)  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4            21.0            20.7            20.2            19.2
#
#    1.0m평균지중온도(°C)  1.5m평균지중온도(°C)  3.0m평균지중온도(°C)  5.0m평균지중온도(°C)
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4            16.9            14.7            11.8            11.5
#
# [5 rows x 69 columns]

# %%
cols = list(df.columns)
print(f"There are {len(cols)} columns")
# Out:
# There are 69 columns

# %% [markdown]
# Note:
# - QC stands for quality control
# - All the temperature related attribute are in celcius degree

# %%
translate_cols_1_week_data =  [ "Branch", 
                    "Branch name",
                    "Date and Time", 
                    "Temperature(°C)",
                    "Temperature QC Flag",
                    "precipitation(mm)",
                    "Precipitation QC flag",
                    "wind speed(m/s)",
                    "Wind speed QC flag",
                    "Wind Direction(16 directions)",
                    "Wind direction QC flag", 
                    "Humidity(%)",
                    "Humidity QC flag",
                    'Vapor pressure(hPa)',
                    'Dew Point Temperature(°C)',
                    'Local air pressure(hPa)',
                    'Local Barometric Pressure QC Flag',
                    "Air pressure at sea(hPa)",
                    "Spong Barometric Pressure QC Flag",
                    'Daylight(hr)',
                    "Sunlight QC Flag",
                    'Sunshine(MJ/m2)',
                    "Sunshine QC Flag",
                    "Snowfall(cm)",
                    "Three-hour new theory(cm)",
                    "Total cloud volume(10th quartile)",
                    "Middle and low-order cloud(10th-quartile)",
                    'Woonhyeong(Old form abbreviation))',
                    "Minimum cargo(100m)",
                    "Visibility(10m)",
                    'ground status(ground status code)',
                    'Development number(domestic)',
                    'ground temperature(°C)',
                    'ground temperature QC flag',
                    '5 cm underground temperature(°C)',
                    '10cm underground temperature(°C)',
                    "20 cm Underground Temperature(°C)",
                    "30cm underground temperature(°C)",
                  ]

translate_cols_1_week_data = list(map(lambda s: s.lower().replace(" ", "_"), translate_cols_1_week_data))
len(translate_cols_1_week_data)

# %%
translate_cols =  [ "Point",
                    "Branch name",
                    "Date and time",
                    "Average temperature",
                    "Average Maximum Temperature",
                    "Average Lowest Temperature",
                    "Maximum temperature",
                    "Minimum temperature",
                    "The day when the highest temperature appeared (yyyyymmdd)",
                    "The day when the lowest temperature appeared (yyyyymmdd)",
                    "Average local pressure (hPa)",
                    "Average sea pressure (hPa)",
                    "Maximum sea pressure (hPa)",
                    "Minimum sea pressure (hPa)",
                    "Maximum sea pressure day (yyyyymmdd)",
                    "Minimum sea pressure day (yyyyymmdd)",
                    "Average water vapor pressure (hPa)",
                    "Maximum water vapor pressure (hPa)",
                    "Minimum water vapor pressure (hPa)",
                    "Maximum water vapor pressure day (yyyyymmdd)",
                    "Minimum water vapor pressure day (yyyyymmdd)",
                    "Average dew point temperature (°C)",
                    "Average Relative Humidity (%)",
                    "Minimum relative humidity (%)",
                    "Minimum Relative Humidity Day (yyyyymmdd)",
                    "Monthly precipitation (00 to 24h only) (mm)",
                    "Maximum daily precipitation (mm)",
                    "Maximum precipitation per hour (mm)",
                    "Maximum precipitation for 10 minutes (mm)",
                    "The day when the highest daily precipitation appeared (yyyyymmdd)",
                    "The day when the highest precipitation for an hour appeared (yyyyymmdd)",
                    "10 min maximum precipitation day (yyyyymmdd)",
                    "Small total evaporation (mm)",
                    "Small daily maximum evaporation (mm)",
                    "Large total evaporation amount (mm)",
                    "Large daily maximum evaporation (mm)",
                    "Small daily maximum evaporation date (yyyyymmdd)",
                    "Large daily maximum evaporation date (yyyyymmdd)",
                    "Average wind speed (m/s)",
                    "Maximum wind speed (m/s)",
                    "Maximum instantaneous wind speed (m/s)",
                    "Maximum wind speed wind direction (16 directions)",
                    "Maximum instantaneous wind speed wind direction (16 directions)",
                    "Maximum wind speed day (yyyyymmdd)",
                    "Maximum instantaneous wind speed day (yyyyymmdd)",
                    "Highest wind direction (16 directions)",
                    "Average luck (1/10)",
                    "Average middle and lower floor cloud (1/10)",
                    "Total sunlight hours (hr)",
                    "Sunlight rate (%)",
                    "Total solar radiation (MJ/m2)",
                    "Deepest snow (cm)",
                    "Deepest and thin snow (cm)",
                    "3 hours new snowflake (cm)",
                    "The day when the deepest snowfall appeared (yyyyymmdd)",
                    "The day when the most recent snowstorm appeared (yyyyymmdd)",
                    "Average minimum phase temperature",
                    "Minimum phase temperature",
                    "The day when the minimum phase temperature appeared (yyyyymmdd)",
                    "Average ground temperature",
                    "0.05 m average ground temperature",
                    "0.1 m average ground temperature",
                    "0.2 m average ground temperature",
                    "0.3 m average ground temperature",
                    "0.5 m average ground temperature",
                    "1.0 m average ground temperature",
                    "1.5 m average ground temperature",
                    "3.0 m average ground temperature",
                    "5.0 m average ground temperature",
                ]

translate_cols = list(map(lambda s: s.lower().replace(" ", "_"), translate_cols))
len(translate_cols)
# Out:
# 69

# %%
df.columns = translate_cols
df.head()
# Out:
#    point branch_name date_and_time  average_temperature  \
# 0     90          속초       2022-05                 18.5
# 1     90          속초       2022-06                 20.9
# 2     90          속초       2022-07                 24.3
# 3     90          속초       2022-08                  NaN
# 4     93         북춘천       2022-05                 17.2
#
#    average_maximum_temperature  average_lowest_temperature  \
# 0                         23.7                        13.1
# 1                         24.7                        17.6
# 2                         27.7                        21.9
# 3                          NaN                         NaN
# 4                         25.0                         9.4
#
#    maximum_temperature  minimum_temperature  \
# 0                 33.5                  5.8
# 1                 34.6                 10.1
# 2                 33.4                 18.8
# 3                 35.5                 20.3
# 4                 30.7                  2.4
#
#    the_day_when_the_highest_temperature_appeared_(yyyyymmdd)  \
# 0                                           20220528
# 1                                           20220625
# 2                                           20220708
# 3                                           20220806
# 4                                           20220524
#
#    the_day_when_the_lowest_temperature_appeared_(yyyyymmdd)  ...  \
# 0                                           20220502         ...
# 1                                           20220608         ...
# 2                                           20220723         ...
# 3                                           20220810         ...
# 4                                           20220501         ...
#
#    average_ground_temperature  0.05_m_average_ground_temperature  \
# 0                        24.0                                NaN
# 1                        24.8                                NaN
# 2                        28.5                                NaN
# 3                         NaN                                NaN
# 4                        22.7                               21.0
#
#    0.1_m_average_ground_temperature  0.2_m_average_ground_temperature  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                              21.0                              20.7
#
#    0.3_m_average_ground_temperature  0.5_m_average_ground_temperature  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                              20.2                              19.2
#
#    1.0_m_average_ground_temperature  1.5_m_average_ground_temperature  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                              16.9                              14.7
#
#    3.0_m_average_ground_temperature  5.0_m_average_ground_temperature
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                              11.8                              11.5
#
# [5 rows x 69 columns]

# %%
df.describe()
# Out:
#             point  average_temperature  average_maximum_temperature  \
# count  380.000000           285.000000                   285.000000
# mean   197.347368            22.123158                    27.338596
# std     64.428933             3.459660                     2.796751
# min     90.000000            13.400000                    18.200000
# 25%    136.000000            18.800000                    25.200000
# 50%    202.000000            22.500000                    27.400000
# 75%    258.000000            25.500000                    29.800000
# max    295.000000            28.400000                    32.700000
#
#        average_lowest_temperature  maximum_temperature  minimum_temperature  \
# count                  285.000000           380.000000           380.000000
# mean                    17.552632            32.892105            14.838947
# std                      4.775034             2.375755             7.323815
# min                      6.100000            22.900000            -2.700000
# 25%                     13.600000            31.500000             8.850000
# 50%                     18.600000            33.200000            16.050000
# 75%                     21.900000            34.700000            21.000000
# max                     25.700000            37.900000            27.000000
#
#        the_day_when_the_highest_temperature_appeared_(yyyyymmdd)  \
# count                                       3.800000e+02
# mean                                        2.022067e+07
# std                                         1.053953e+02
# min                                         2.022051e+07
# 25%                                         2.022058e+07
# 50%                                         2.022067e+07
# 75%                                         2.022075e+07
# max                                         2.022081e+07
#
#        the_day_when_the_lowest_temperature_appeared_(yyyyymmdd)  \
# count                                       3.800000e+02
# mean                                        2.022066e+07
# std                                         1.162750e+02
# min                                         2.022050e+07
# 25%                                         2.022058e+07
# 50%                                         2.022066e+07
# 75%                                         2.022075e+07
# max                                         2.022081e+07
#
#        average_local_pressure_(hpa)  average_sea_pressure_(hpa)  ...  \
# count                    285.000000                  285.000000  ...
# mean                     996.902807                 1008.645614  ...
# std                       14.175924                    2.816480  ...
# min                      922.000000                 1004.200000  ...
# 25%                      992.800000                 1006.300000  ...
# 50%                     1001.000000                 1007.600000  ...
# 75%                     1004.600000                 1011.900000  ...
# max                     1013.300000                 1014.500000  ...
#
#        average_ground_temperature  0.05_m_average_ground_temperature  \
# count                  285.000000                          84.000000
# mean                    26.455439                          24.848810
# std                      2.686799                           2.986778
# min                     17.400000                          19.000000
# 25%                     24.500000                          22.650000
# 50%                     26.500000                          24.550000
# 75%                     28.600000                          27.625000
# max                     32.500000                          30.400000
#
#        0.1_m_average_ground_temperature  0.2_m_average_ground_temperature  \
# count                         84.000000                         84.000000
# mean                          24.379762                         23.977381
# std                            3.084035                          3.132586
# min                           18.200000                         18.200000
# 25%                           21.850000                         21.550000
# 50%                           24.150000                         23.800000
# 75%                           27.150000                         26.900000
# max                           30.600000                         30.600000
#
#        0.3_m_average_ground_temperature  0.5_m_average_ground_temperature  \
# count                         84.000000                         39.000000
# mean                          23.503571                         22.787179
# std                            3.203629                          3.260625
# min                           17.400000                         16.600000
# 25%                           20.900000                         20.000000
# 50%                           23.550000                         22.800000
# 75%                           26.400000                         25.300000
# max                           30.200000                         29.500000
#
#        1.0_m_average_ground_temperature  1.5_m_average_ground_temperature  \
# count                         39.000000                         39.000000
# mean                          20.607692                         18.692308
# std                            3.260722                          3.085994
# min                           15.200000                         13.300000
# 25%                           17.850000                         16.550000
# 50%                           20.600000                         19.100000
# 75%                           23.000000                         20.650000
# max                           27.200000                         24.800000
#
#        3.0_m_average_ground_temperature  5.0_m_average_ground_temperature
# count                         39.000000                         39.000000
# mean                          15.620513                         14.728205
# std                            2.408120                          1.589430
# min                           11.600000                         11.500000
# 25%                           13.950000                         13.450000
# 50%                           15.600000                         15.000000
# 75%                           17.400000                         16.050000
# max                           22.000000                         17.700000
#
# [8 rows x 67 columns]

# %%
## Drop columns with more than 5% of data is NaN values.

isNan = round(df.isnull().sum()/len(df)*100, 2)
isNan.drop(isNan[isNan < 5].index, inplace=True) 
dropCols = list(isNan.index)
df_short = df.drop(dropCols, axis=1)
print(f"{len(dropCols)} columns are dropped: ")
df_short.head()
# Out:
# 34 columns are dropped:
#    point branch_name date_and_time  maximum_temperature  minimum_temperature  \
# 0     90          속초       2022-05                 33.5                  5.8
# 1     90          속초       2022-06                 34.6                 10.1
# 2     90          속초       2022-07                 33.4                 18.8
# 3     90          속초       2022-08                 35.5                 20.3
# 4     93         북춘천       2022-05                 30.7                  2.4
#
#    the_day_when_the_highest_temperature_appeared_(yyyyymmdd)  \
# 0                                           20220528
# 1                                           20220625
# 2                                           20220708
# 3                                           20220806
# 4                                           20220524
#
#    the_day_when_the_lowest_temperature_appeared_(yyyyymmdd)  \
# 0                                           20220502
# 1                                           20220608
# 2                                           20220723
# 3                                           20220810
# 4                                           20220501
#
#    maximum_sea_pressure_(hpa)  minimum_sea_pressure_(hpa)  \
# 0                      1022.7                       997.0
# 1                      1016.5                       991.1
# 2                      1014.9                       996.8
# 3                      1009.7                      1001.8
# 4                      1022.4                       998.6
#
#    maximum_sea_pressure_day_(yyyyymmdd)  ...  \
# 0                              20220508  ...
# 1                              20220611  ...
# 2                              20220729  ...
# 3                              20220804  ...
# 4                              20220508  ...
#
#    maximum_instantaneous_wind_speed_(m/s)  \
# 0                                    15.9
# 1                                    14.7
# 2                                    10.3
# 3                                     9.9
# 4                                    15.6
#
#    maximum_wind_speed_wind_direction_(16_directions)  \
# 0                                                270
# 1                                                110
# 2                                                360
# 3                                                360
# 4                                                230
#
#    maximum_instantaneous_wind_speed_wind_direction_(16_directions)  \
# 0                                                290
# 1                                                250
# 2                                                360
# 3                                                360
# 4                                                230
#
#    maximum_wind_speed_day_(yyyyymmdd)  \
# 0                            20220507
# 1                            20220606
# 2                            20220714
# 3                            20220805
# 4                            20220501
#
#    maximum_instantaneous_wind_speed_day_(yyyyymmdd)  \
# 0                                          20220504
# 1                                          20220628
# 2                                          20220714
# 3                                          20220805
# 4                                          20220501
#
#    highest_wind_direction_(16_directions)  total_sunlight_hours_(hr)  \
# 0                                     270                      312.7
# 1                                     140                      169.6
# 2                                     140                      135.5
# 3                                     140                       71.4
# 4                                     200                      281.3
#
#    sunlight_rate_(%)  minimum_phase_temperature  \
# 0              70.76                        5.9
# 1              38.26                        9.0
# 2              30.07                       19.8
# 3              39.36                       20.3
# 4              63.79                      -10.2
#
#    the_day_when_the_minimum_phase_temperature_appeared_(yyyyymmdd)
# 0                                           20220502
# 1                                           20220608
# 2                                           20220723
# 3                                           20220810
# 4                                           20220526
#
# [5 rows x 35 columns]

# %%
branch_name = df.branch_name.unique()
branch_name
# Out:
# array(['속초', '북춘천', '철원', '동두천', '파주', '대관령', '춘천', '백령도', '북강릉', '강릉',
#        '동해', '서울', '인천', '원주', '울릉도', '수원', '영월', '충주', '서산', '울진', '청주',
#        '대전', '추풍령', '안동', '상주', '포항', '군산', '대구', '전주', '울산', '창원', '광주',
#        '부산', '통영', '목포', '여수', '흑산도', '완도', '고창', '순천', '홍성', '제주', '고산',
#        '성산', '서귀포', '진주', '강화', '양평', '이천', '인제', '홍천', '태백', '정선군', '제천',
#        '보은', '천안', '보령', '부여', '금산', '세종', '부안', '임실', '정읍', '남원', '장수',
#        '고창군', '영광군', '김해시', '순창군', '북창원', '양산시', '보성군', '강진군', '장흥', '해남',
#        '고흥', '의령군', '함양군', '광양시', '진도군', '봉화', '영주', '문경', '청송군', '영덕',
#        '의성', '구미', '영천', '경주시', '거창', '합천', '밀양', '산청', '거제', '남해'],
#       dtype=object)

# %% [markdown]
# ## TODO: Plot graphs
